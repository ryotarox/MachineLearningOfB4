# %%
import numpy as np
import pandas as pd
import warnings
import datetime
import numpy
warnings.simplefilter('ignore')
import math
from statistics import mean
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import timedelta
from sklearn.metrics import mean_squared_error


#from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout

from sklearn.model_selection import train_test_split
import category_encoders as ce

# %%
df
# Out:
#    group  test  score
# 9      A     1     35
# 15     A     2     52
# 19     A     2     44
# 11     B     2     50
# 1      B     1     96
# 14     B     2      6
# 13     B     1     75
# 18     B     1     18
# 0      B     1     83
# 6      B     1     32
# 5      B     1     50
# 4      B     1     97
# 8      B     1     66
# 7      C     1     91
# 10     C     1     78
# 2      C     2      5
# 12     C     1     21
# 16     C     2     51
# 17     C     1     66
# 3      C     2      9

# %%
filename = "Sarimax_24_predict/station_10.csv"
dataframe1 = pd.read_csv(filename)
dataframe1["05"].values
# Out:
# array([3.0002, 2.3427, 2.8321, 4.0061, 5.7078, 4.2409, 4.1639, 4.8749,
#        4.0827, 3.8229])

# %%
filename = "Hakohige_rmse_v0.csv"
dataframe = pd.read_csv(filename)
Figure = plt.figure(figsize=(16,8))
sns.boxplot(x='group', y='score', hue='test', data=dataframe)
# Out:
# <AxesSubplot:xlabel='group', ylabel='score'>

# %%
filename = "Hakohige_rmse_v0.csv"
dataframe = pd.read_csv(filename)
Figure = plt.figure(figsize=(16,8))
sns.boxplot(x='group', y='score', data=dataframe)
# Out:
# <AxesSubplot:xlabel='group', ylabel='score'>

# %%
filename = "Hakohige_rmse_v1.csv"
dataframe = pd.read_csv(filename)
Figure = plt.figure(figsize=(16,8))
sns.boxplot(x='method', y='score', data=dataframe)
# Out:
# <AxesSubplot:xlabel='method', ylabel='score'>

# %%
filename = "Sarimax_24_predict/var/station_10.csv"
dataframe1 = pd.read_csv(filename)
dataframe1["05"].values
# Out:
# array([ 6.0812 ,  0.38829,  7.7348 ,  9.4244 , 23.521  , 13.892  ,
#        18.968  ,  8.3228 , 13.136  , 15.584  ])

# %%
filename = "Hakohige_var_v0.csv"
dataframe = pd.read_csv(filename)
Figure = plt.figure(figsize=(16,8))
sns.boxplot(x='method', y='abs(var)', hue='month', data=dataframe)
# Out:
# <AxesSubplot:xlabel='method', ylabel='abs(var)'>

# %%
filename = "Hakohige_var_v0.csv"
dataframe = pd.read_csv(filename)
Figure = plt.figure(figsize=(16,8))
sns.boxplot(x='method', y='abs(var)', data=dataframe)
# Out:
# <AxesSubplot:xlabel='method', ylabel='abs(var)'>
